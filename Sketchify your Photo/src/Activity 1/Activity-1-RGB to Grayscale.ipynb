# %% [markdown]
# ## Convert the color image to grayscale
#
# This should be really easy to do even for an OpenCV novice. Images can be opened with cv2.imread and can be converted between color spaces with cv2.cvtColor. Alternatively, you can pass an additional argument to cv2.imread that specifies the color mode in which to open the image.

# %%
#import the open cv library and matplotlib

# %% [markdown]
# <details>
#     <summary>Solution</summary>
# <p>
#
# ```python
# import cv2
# %matplotlib inline
# import matplotlib.pyplot as plt
#
# ```
#
# </p>
# </details>

# %%
#read image using cv2

# %% [markdown]
# <details>
#     <summary>Solution</summary>
# <p>
#
# ```python
# image = cv2.imread("~Rutuja\\OpenSrc\\Miscellaneous\\Sketchifyyour photo\\images\\rutuja.jpeg")
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ![cat.jpeg](attachment:cat.jpeg)

# %%
#Display the loaded images using pyplot

# %% [markdown]
# <details>
#     <summary>Solution</summary>
# <p>
#
# ```python
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.show()
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ![gray.png](attachment:gray.png)

# %% [markdown]
# ### Further Read
#
# Introduction to Open CV: https://docs.opencv.org/master/d1/dfb/intro.html <br>
# Computer Vision Fundamentals: https://www.mygreatlearning.com/blog/what-is-computer-vision-the-basics/#:~:text=Computer%20vision%20is%20a%20field,them%20to%20define%20the%20attributes.
